# %%
import pandas as pd
df = pd.read_csv('heart.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df['age'].dtype
# Out:
# dtype('int64')

# %%
df['cp'].replace(0, 'a', inplace=True)
df['cp'].replace(1, 'b', inplace=True)
df['cp']
# Out:
# 0       a
# 1       a
# 2       a
# 3       a
# 4       a
#        ..
# 1020    b
# 1021    a
# 1022    a
# 1023    a
# 1024    a
# Name: cp, Length: 1025, dtype: object

# %%
df['cp'].dtype
# Out:
# dtype('O')

# %%
x = []
for i in range(len(df)):
    x.append('a')
df['x'] = x
df.head()
# Out:
#    age  sex cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1  a       125   212    0        1      168      0      1.0      2
# 1   53    1  a       140   203    1        0      155      1      3.1      0
# 2   70    1  a       145   174    0        1      125      1      2.6      0
# 3   61    1  a       148   203    0        1      161      0      0.0      2
# 4   62    0  a       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target  x
# 0   2     3       0  a
# 1   0     3       0  a
# 2   0     3       0  a
# 3   1     3       0  a
# 4   3     2       0  a

# %%
df['x'].dtype
# Out:
# dtype('O')

# %%
df = pd.read_csv('Clean_Dataset.csv')
df.head()
# Out:
#    Unnamed: 0   airline   flight source_city departure_time stops  \
# 0           0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1           1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2           2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3           3   Vistara   UK-995       Delhi        Morning  zero
# 4           4   Vistara   UK-963       Delhi        Morning  zero
#
#     arrival_time destination_city    class  duration  days_left  price
# 0          Night           Mumbai  Economy      2.17          1   5953
# 1        Morning           Mumbai  Economy      2.33          1   5953
# 2  Early_Morning           Mumbai  Economy      2.17          1   5956
# 3      Afternoon           Mumbai  Economy      2.25          1   5955
# 4        Morning           Mumbai  Economy      2.33          1   5955

# %%
print(df['airline'].dtype)
# Out:
# object

# %%
print(df['days_left'].dtype == 'int64')
# Out:
# True

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'airline', 'flight', 'source_city', 'departure_time',
#        'stops', 'arrival_time', 'destination_city', 'class', 'duration',
#        'days_left', 'price'],
#       dtype='object')

# %%
df
# Out:
#         Unnamed: 0   airline   flight source_city departure_time stops  \
# 0                0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1                1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2                2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3                3   Vistara   UK-995       Delhi        Morning  zero
# 4                4   Vistara   UK-963       Delhi        Morning  zero
# ...            ...       ...      ...         ...            ...   ...
# 300148      300148   Vistara   UK-822     Chennai        Morning   one
# 300149      300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150      300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151      300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152      300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price
# ...

# %%
df = pd.read_csv('heart.csv')
df = df.head(10)
df
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 5   58    0   0       100   248    0        0      122      0      1.0      1
# 6   58    1   0       114   318    0        2      140      0      4.4      0
# 7   55    1   0       160   289    0        0      145      1      0.8      1
# 8   46    1   0       120   249    0        0      144      0      0.8      2
# 9   54    1   0       122   286    0        0      116      1      3.2      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# ...

# %%
df = df.sort_values('age')
df
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 8   46    1   0       120   249    0        0      144      0      0.8      2
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 9   54    1   0       122   286    0        0      116      1      3.2      1
# 7   55    1   0       160   289    0        0      145      1      0.8      1
# 5   58    0   0       100   248    0        0      122      0      1.0      1
# 6   58    1   0       114   318    0        2      140      0      4.4      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 2   70    1   0       145   174    0        1      125      1      2.6      0
#
#    ca  thal  target
# 8   0     3       0
# 0   2     3       0
# 1   0     3       0
# 9   2     2       0
# ...

# %%
df.head(3)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 8   46    1   0       120   249    0        0      144      0      0.8      2
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
#
#    ca  thal  target
# 8   0     3       0
# 0   2     3       0
# 1   0     3       0

# %%
def fillAllTheWaySplit(lenThreshold, partitions):
    def Try(currIndexOfThreshold, currPartitions):
        if currIndexOfThreshold == lenThreshold:
            return
        if currPartitions == partitions:
            element.append(currIndexOfThreshold)
            ans.append(element.copy())
            element.pop()
            Try(currIndexOfThreshold + 1, currPartitions)
        if currPartitions < partitions:
            element.append(currIndexOfThreshold)
            Try(currIndexOfThreshold + 1, currPartitions + 1)
            element.pop()
            Try(currIndexOfThreshold + 1, currPartitions)
    ans = []
    element = []
    Try(0, 2)
    return ans

# %%
fillAllTheWaySplit(10, 4)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# e:\DecisionTree_C4.5\test.ipynb Cell 16 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/e%3A/DecisionTree_C4.5/test.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> fillAllTheWaySplit(10, 4)
#
# e:\DecisionTree_C4.5\test.ipynb Cell 16 in fillAllTheWaySplit(lenThreshold, partitions)
#       <a href='vscode-notebook-cell:/e%3A/DecisionTree_C4.5/test.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a> ans = []
#       <a href='vscode-notebook-cell:/e%3A/DecisionTree_C4.5/test.ipynb#X21sZmlsZQ%3D%3D?line=2'>3</a> element = []
# ----> <a href='vscode-notebook-cell:/e%3A/DecisionTree_C4.5/test.ipynb#X21sZmlsZQ%3D%3D?line=3'>4</a> Try(0, 2)
#       <a href='vscode-notebook-cell:/e%3A/DecisionTree_C4.5/test.ipynb#X21sZmlsZQ%3D%3D?line=4'>5</a> def Try(currIndexOfThreshold, currPartitions):
# ...

# %%
df
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 8   46    1   0       120   249    0        0      144      0      0.8      2
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 9   54    1   0       122   286    0        0      116      1      3.2      1
# 7   55    1   0       160   289    0        0      145      1      0.8      1
# 5   58    0   0       100   248    0        0      122      0      1.0      1
# 6   58    1   0       114   318    0        2      140      0      4.4      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 2   70    1   0       145   174    0        1      125      1      2.6      0
#
#    ca  thal  target
# 8   0     3       0
# 0   2     3       0
# 1   0     3       0
# 9   2     2       0
# ...

# %%
df1 = df.iloc[0:2]
df2 = df.iloc[2:]
df1, df2
# Out:
# (   age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
#  8   46    1   0       120   249    0        0      144      0      0.8      2
#  0   52    1   0       125   212    0        1      168      0      1.0      2
#
#     ca  thal  target
#  8   0     3       0
#  0   2     3       0  ,
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
#  1   53    1   0       140   203    1        0      155      1      3.1      0
#  9   54    1   0       122   286    0        0      116      1      3.2      1
#  7   55    1   0       160   289    0        0      145      1      0.8      1
#  5   58    0   0       100   248    0        0      122      0      1.0      1
#  6   58    1   0       114   318    0        2      140      0      4.4      0
#  3   61    1   0       148   203    0        1      161      0      0.0      2
#  4   62    0   0       138   294    1        1      106      0      1.9      1
# ...

# %%
df = pd.read_csv('Clean_Dataset.csv')
df.head()
# Out:
#    Unnamed: 0   airline   flight source_city departure_time stops  \
# 0           0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1           1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2           2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3           3   Vistara   UK-995       Delhi        Morning  zero
# 4           4   Vistara   UK-963       Delhi        Morning  zero
#
#     arrival_time destination_city    class  duration  days_left  price
# 0          Night           Mumbai  Economy      2.17          1   5953
# 1        Morning           Mumbai  Economy      2.33          1   5953
# 2  Early_Morning           Mumbai  Economy      2.17          1   5956
# 3      Afternoon           Mumbai  Economy      2.25          1   5955
# 4        Morning           Mumbai  Economy      2.33          1   5955

# %%
df = df.sort_values('flight')
df.head()
# Out:
#         Unnamed: 0 airline  flight source_city departure_time stops  \
# 179354      179354  Indigo  6E-102   Hyderabad        Evening  zero
# 167667      167667  Indigo  6E-102   Hyderabad        Evening   one
# 180023      180023  Indigo  6E-102   Hyderabad        Evening  zero
# 169558      169558  Indigo  6E-102   Hyderabad        Evening   one
# 168011      168011  Indigo  6E-102   Hyderabad        Evening   one
#
#        arrival_time destination_city    class  duration  days_left  price
# 179354      Evening          Chennai  Economy      1.25         37   1788
# 167667        Night        Bangalore  Economy      4.42         23   3072
# 180023      Evening          Chennai  Economy      1.25         44   1788
# 169558        Night        Bangalore  Economy      4.42         40   1755
# 168011        Night        Bangalore  Economy      4.42         26   3072
